# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly
import plotly.graph_objs as go
import plotly.express as px
import ipywidgets as widgets
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings('ignore')

#data = pd.read_csv("DATOS ADD_VISUALIZACION.CSV", decimal=',')
data = pd.read_csv("https://raw.githubusercontent.com/wilderhp/VitaminaD/main/Vitamina_D_Visualizacion_23092022_02.csv",sep=';', decimal=',')
data
# Out:
#                  FECHA_PETICION   Año LABORATORIO  PETICION   Identificador  \
# 0       2018-01-02 08:17:18,000  2018    SANTIAGO   1483128  11209350793971
# 1       2018-01-02 08:18:28,000  2018    SANTIAGO   1483181  11254355333953
# 2       2018-01-02 08:24:12,000  2018    SANTIAGO   1483186  11109356703927
# 3       2018-01-02 08:34:16,000  2018    SANTIAGO   1483291  11103356623953
# 4       2018-01-02 08:37:10,000  2018    SANTIAGO   1483324  11244356743906
# ...                         ...   ...         ...       ...             ...
# 154732  2021-12-31 11:42:19,000  2021    SANTIAGO   6583168  11170358503907
# 154733  2021-12-31 11:49:45,000  2021    SANTIAGO   6583212  11160353023907
# 154734  2021-12-31 11:56:34,000  2021    SANTIAGO   6583254  11132355283979
# 154735  2021-12-31 12:35:14,000  2021    SANTIAGO   6583737   1180035634398
# 154736  2021-12-31 13:01:22,000  2021    SANTIAGO   6583960  11271358603946
#
#        SEXO Adulto_Niño MACROZONA Estaciones_año  Edad  CREATININA  FOSFORO  \
# 0         M        Niño    CENTRO         VERANO    16        0.90      5.5
# 1         F      Adulto    CENTRO         VERANO    33         NaN      NaN
# 2         M      Adulto    CENTRO         VERANO    45        0.80      4.1
# 3         F      Adulto    CENTRO         VERANO    52         NaN      NaN
# 4         F        Niño    CENTRO         VERANO     4        0.40      3.9
# ...     ...         ...       ...            ...   ...         ...      ...
# 154732    F      Adulto    CENTRO      PRIMAVERA    32        0.67      3.4
# 154733    M      Adulto    CENTRO      PRIMAVERA    36         NaN      3.4
# 154734    F      Adulto    CENTRO      PRIMAVERA    44         NaN      4.5
# 154735    F      Adulto    CENTRO      PRIMAVERA    63         NaN      NaN
# 154736    M        Niño    CENTRO      PRIMAVERA     1        0.31      5.9
#
#         CALCIO  VITAMINA D  COVID-19
# 0         10.9       22.80       NaN
# 1          NaN       15.00       NaN
# 2          9.6       17.10       NaN
# 3          NaN       34.40       NaN
# 4          9.9       35.10       NaN
# ...        ...         ...       ...
# 154732     9.0        5.75       NaN
# 154733     9.3        6.79       NaN
# 154734     9.6       31.80       NaN
# 154735     NaN       14.50       NaN
# 154736     9.7        6.61       NaN
#
# [154737 rows x 15 columns]

# %%
data.columns = data.columns.str.upper()
data.head(5)
# Out:
#             FECHA_PETICION   AÑO LABORATORIO  PETICION   IDENTIFICADOR SEXO  \
# 0  2018-01-02 08:17:18,000  2018    SANTIAGO   1483128  11209350793971    M
# 1  2018-01-02 08:18:28,000  2018    SANTIAGO   1483181  11254355333953    F
# 2  2018-01-02 08:24:12,000  2018    SANTIAGO   1483186  11109356703927    M
# 3  2018-01-02 08:34:16,000  2018    SANTIAGO   1483291  11103356623953    F
# 4  2018-01-02 08:37:10,000  2018    SANTIAGO   1483324  11244356743906    F
#
#   ADULTO_NIÑO MACROZONA ESTACIONES_AÑO  EDAD  CREATININA  FOSFORO  CALCIO  \
# 0        Niño    CENTRO         VERANO    16         0.9      5.5    10.9
# 1      Adulto    CENTRO         VERANO    33         NaN      NaN     NaN
# 2      Adulto    CENTRO         VERANO    45         0.8      4.1     9.6
# 3      Adulto    CENTRO         VERANO    52         NaN      NaN     NaN
# 4        Niño    CENTRO         VERANO     4         0.4      3.9     9.9
#
#    VITAMINA D  COVID-19
# 0        22.8       NaN
# 1        15.0       NaN
# 2        17.1       NaN
# 3        34.4       NaN
# 4        35.1       NaN

# %%
data = data[data['VITAMINA D']!='2.402.000.203']
data = data[data['VITAMINA D']!='2.920.002.027']
data = data[data['VITAMINA D']!='2.567.000.204']
data['VITAMINA D'] = data['VITAMINA D'].astype(float)

# %%
# Para definir los resultados de la vitamina en base a la tabla en https://tucuerpomehabla.com/la-vitamina-d-clave-en-nuestro-bienestar/
def condicion(x):
    x=int(x)
    if x<20:
        return "Deficiente"
    elif x>=20 and x<30:
        return "Insuficiente"
    elif x>=30 and x<=100:
        return "Deseable"
    else:
        return 'Toxicidad'

def retornarMes(x):
    return mesesDic[str(x)]


data['RESULTADO_VAL']= 1

data['VIT_D_TXT'] = data['VITAMINA D'].apply(condicion)
data
# Out:
#                  FECHA_PETICION   AÑO LABORATORIO  PETICION   IDENTIFICADOR  \
# 0       2018-01-02 08:17:18,000  2018    SANTIAGO   1483128  11209350793971
# 1       2018-01-02 08:18:28,000  2018    SANTIAGO   1483181  11254355333953
# 2       2018-01-02 08:24:12,000  2018    SANTIAGO   1483186  11109356703927
# 3       2018-01-02 08:34:16,000  2018    SANTIAGO   1483291  11103356623953
# 4       2018-01-02 08:37:10,000  2018    SANTIAGO   1483324  11244356743906
# ...                         ...   ...         ...       ...             ...
# 154732  2021-12-31 11:42:19,000  2021    SANTIAGO   6583168  11170358503907
# 154733  2021-12-31 11:49:45,000  2021    SANTIAGO   6583212  11160353023907
# 154734  2021-12-31 11:56:34,000  2021    SANTIAGO   6583254  11132355283979
# 154735  2021-12-31 12:35:14,000  2021    SANTIAGO   6583737   1180035634398
# 154736  2021-12-31 13:01:22,000  2021    SANTIAGO   6583960  11271358603946
#
#        SEXO ADULTO_NIÑO MACROZONA ESTACIONES_AÑO  EDAD  CREATININA  FOSFORO  \
# 0         M        Niño    CENTRO         VERANO    16        0.90      5.5
# 1         F      Adulto    CENTRO         VERANO    33         NaN      NaN
# 2         M      Adulto    CENTRO         VERANO    45        0.80      4.1
# 3         F      Adulto    CENTRO         VERANO    52         NaN      NaN
# 4         F        Niño    CENTRO         VERANO     4        0.40      3.9
# ...     ...         ...       ...            ...   ...         ...      ...
# 154732    F      Adulto    CENTRO      PRIMAVERA    32        0.67      3.4
# 154733    M      Adulto    CENTRO      PRIMAVERA    36         NaN      3.4
# 154734    F      Adulto    CENTRO      PRIMAVERA    44         NaN      4.5
# 154735    F      Adulto    CENTRO      PRIMAVERA    63         NaN      NaN
# 154736    M        Niño    CENTRO      PRIMAVERA     1        0.31      5.9
#
#         CALCIO  VITAMINA D  COVID-19  RESULTADO_VAL     VIT_D_TXT
# 0         10.9       22.80       NaN              1  Insuficiente
# 1          NaN       15.00       NaN              1    Deficiente
# 2          9.6       17.10       NaN              1    Deficiente
# 3          NaN       34.40       NaN              1      Deseable
# 4          9.9       35.10       NaN              1      Deseable
# ...        ...         ...       ...            ...           ...
# 154732     9.0        5.75       NaN              1    Deficiente
# 154733     9.3        6.79       NaN              1    Deficiente
# 154734     9.6       31.80       NaN              1      Deseable
# 154735     NaN       14.50       NaN              1    Deficiente
# 154736     9.7        6.61       NaN              1    Deficiente
#
# [154737 rows x 17 columns]

# %%
def agregar_proporcion(grupo):    
    grupo["PROP"] = grupo['VITAMINA D'] / grupo['VITAMINA D'].sum()
    grupo["PROP_2"] = grupo['RESULTADO_VAL'] / grupo['RESULTADO_VAL'].sum()
    return grupo

df_filter = data.groupby(['AÑO','LABORATORIO','ADULTO_NIÑO']).apply(agregar_proporcion)
df_filter
# Out:
#                  FECHA_PETICION   AÑO LABORATORIO  PETICION   IDENTIFICADOR  \
# 0       2018-01-02 08:17:18,000  2018    SANTIAGO   1483128  11209350793971
# 1       2018-01-02 08:18:28,000  2018    SANTIAGO   1483181  11254355333953
# 2       2018-01-02 08:24:12,000  2018    SANTIAGO   1483186  11109356703927
# 3       2018-01-02 08:34:16,000  2018    SANTIAGO   1483291  11103356623953
# 4       2018-01-02 08:37:10,000  2018    SANTIAGO   1483324  11244356743906
# ...                         ...   ...         ...       ...             ...
# 154732  2021-12-31 11:42:19,000  2021    SANTIAGO   6583168  11170358503907
# 154733  2021-12-31 11:49:45,000  2021    SANTIAGO   6583212  11160353023907
# 154734  2021-12-31 11:56:34,000  2021    SANTIAGO   6583254  11132355283979
# 154735  2021-12-31 12:35:14,000  2021    SANTIAGO   6583737   1180035634398
# 154736  2021-12-31 13:01:22,000  2021    SANTIAGO   6583960  11271358603946
#
#        SEXO ADULTO_NIÑO MACROZONA ESTACIONES_AÑO  EDAD  CREATININA  FOSFORO  \
# 0         M        Niño    CENTRO         VERANO    16        0.90      5.5
# 1         F      Adulto    CENTRO         VERANO    33         NaN      NaN
# 2         M      Adulto    CENTRO         VERANO    45        0.80      4.1
# 3         F      Adulto    CENTRO         VERANO    52         NaN      NaN
# 4         F        Niño    CENTRO         VERANO     4        0.40      3.9
# ...     ...         ...       ...            ...   ...         ...      ...
# 154732    F      Adulto    CENTRO      PRIMAVERA    32        0.67      3.4
# 154733    M      Adulto    CENTRO      PRIMAVERA    36         NaN      3.4
# 154734    F      Adulto    CENTRO      PRIMAVERA    44         NaN      4.5
# 154735    F      Adulto    CENTRO      PRIMAVERA    63         NaN      NaN
# 154736    M        Niño    CENTRO      PRIMAVERA     1        0.31      5.9
#
#         CALCIO  VITAMINA D  COVID-19  RESULTADO_VAL     VIT_D_TXT      PROP  \
# 0         10.9       22.80       NaN              1  Insuficiente  0.000765
# 1          NaN       15.00       NaN              1    Deficiente  0.000041
# 2          9.6       17.10       NaN              1    Deficiente  0.000046
# 3          NaN       34.40       NaN              1      Deseable  0.000093
# 4          9.9       35.10       NaN              1      Deseable  0.001177
# ...        ...         ...       ...            ...           ...       ...
# 154732     9.0        5.75       NaN              1    Deficiente  0.000011
# 154733     9.3        6.79       NaN              1    Deficiente  0.000013
# 154734     9.6       31.80       NaN              1      Deseable  0.000061
# 154735     NaN       14.50       NaN              1    Deficiente  0.000028
# 154736     9.7        6.61       NaN              1    Deficiente  0.000093
#
#           PROP_2
# 0       0.000808
# 1       0.000054
# 2       0.000054
# 3       0.000054
# 4       0.000808
# ...          ...
# 154732  0.000035
# 154733  0.000035
# 154734  0.000035
# 154735  0.000035
# 154736  0.000273
#
# [154737 rows x 19 columns]

# %%
result_x=df_filter.groupby(['AÑO','MACROZONA','ESTACIONES_AÑO','ADULTO_NIÑO','VIT_D_TXT']).PROP_2.sum().reset_index()
result_x
# Out:
#       AÑO MACROZONA ESTACIONES_AÑO ADULTO_NIÑO     VIT_D_TXT    PROP_2
# 0    2018    CENTRO       INVIERNO      Adulto    Deficiente  0.822544
# 1    2018    CENTRO       INVIERNO      Adulto      Deseable  0.041759
# 2    2018    CENTRO       INVIERNO      Adulto  Insuficiente  0.191232
# 3    2018    CENTRO       INVIERNO      Adulto     Toxicidad  0.000109
# 4    2018    CENTRO       INVIERNO        Niño    Deficiente  0.697322
# ..    ...       ...            ...         ...           ...       ...
# 312  2021       SUR         VERANO      Adulto  Insuficiente  0.369881
# 313  2021       SUR         VERANO      Adulto     Toxicidad  0.001152
# 314  2021       SUR         VERANO        Niño    Deficiente  0.425896
# 315  2021       SUR         VERANO        Niño      Deseable  0.120400
# 316  2021       SUR         VERANO        Niño  Insuficiente  0.375736
#
# [317 rows x 6 columns]

# %%
def update(year,zona):
  global df_filter

  fig = make_subplots(
    rows=2, cols=1,
    row_heights = [0.2, 0.8],
    specs=[[ {"type": "domain"}],
           [ {"type": "domain"}]])
 
  if zona !="ALL":
    df = df_filter.query(f"MACROZONA == '{zona.upper()}'")
  else:
    df = df_filter
    
  if year !="ALL":
    df = df.query(f"AÑO == {year}")

  
  # Treemap
  fig.add_trace(
    px.treemap(df,values="PROP",color = "ESTACIONES_AÑO",path = ['MACROZONA','ESTACIONES_AÑO','VIT_D_TXT'],hover_name = "MACROZONA").data[0],
    row=1, col=1
    
    )

  # Sunburts
  fig2 = px.sunburst(df, path=['AÑO',"LABORATORIO","SEXO","ADULTO_NIÑO"], values='RESULTADO_VAL')

  fig.add_trace(
      go.Figure(go.Sunburst(
        labels=fig2['data'][0]['labels'],
        parents=fig2['data'][0]['parents'],
        values=fig2['data'][0]['values'],
        ids=fig2['data'][0]['ids'],
        branchvalues='total',
        #marker=dict(colorscale='Rdbu'),
        hovertemplate='<b>%{label}:</b> <br> Total : %{value} <extra></extra>',
        maxdepth=4
      )).data[0], row=2, col=1)
  
  fig2.update_traces(textinfo="label+percent parent")

  fig.update_layout(
    template="plotly_white",
    margin=dict(r=0, t=0, b=0, l=0),
    height = 800,
    #width = 1200,
      
  )
  
  
  fig.show()

dropdown_año = widgets.Dropdown(
    value='ALL', 
    options=['ALL','2018', '2019', '2020', '2021'], 
    description='Año :'
)

dropdown_zona = widgets.Dropdown(
    value='ALL', 
    options=['ALL','Norte', 'Centro', 'Sur'], 
    description='Zona :'
)

widgets.interact(update, year = dropdown_año, zona=dropdown_zona)
# Out:
# interactive(children=(Dropdown(description='Año :', options=('ALL', '2018', '2019', '2020', '2021'), value='AL…
# <function __main__.update(year, zona)>
